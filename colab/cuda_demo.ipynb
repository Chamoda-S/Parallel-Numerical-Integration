# %% [markdown]
# # CUDA Demo (Colab)
#
# This notebook runs the CUDA demo on Google Colab.
#
# Notes:
# - Do NOT copy or include any `/content#` prompt when copying commands — Colab shows that prompt in some outputs, but you should only run the command text itself.
# - Use `Runtime` → `Change runtime type` → `GPU` before running the cells for GPU access.
#
# Run the cells below in order.

# %%
# %%bash
# # Ensure nvcc is available; if not, attempt a simple apt-based install (may be older).
# if ! command -v nvcc >/dev/null 2>&1; then
#   echo "nvcc not found, attempting to install nvidia-cuda-toolkit (may take a few minutes)..."
#   apt-get update -qq
#   apt-get install -y -qq nvidia-cuda-toolkit
# fi
#
# echo 'nvcc version:'
# nvcc --version || true

# %%
# Run the repository helper script (no leading prompt; runs the compile+demo).
# !bash colab/run_cuda_colab.sh
